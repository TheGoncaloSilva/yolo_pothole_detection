# %% [markdown]
# # Load results from every run

# %%
import os

rootFolder: str = "results"

# %%
trainingResults: dict = {
     "yolov5nu_250_epochs_10_patience":
    {
        "platform": "jetson",
        "model": "yolov5n",
        "epochs": 250,
        "patience": 10,
        "dataset": "full",
        "training_time": 45.59, # in hours
        "optimizer": "auto",
        "path": os.path.join(rootFolder, "yolov5nu_250_epochs_10_patience", "results.csv"),
    },
    "yolov8n_20_epochs": 
    {
        "model": "yolov8n",
        "platform": "kaggle",
        "epochs": 20,
        "patience": 100,
        "dataset": "full",
        "optimizer": "auto",
        "training_time": 0.32, # in hours
        "path": os.path.join(rootFolder, "yolov8n_20_epochs", "runs", "detect", "train", "results.csv"),
    },
    "yolov11n_20_epochs":
    {
        "model": "yolov11n",
        "platform": "kaggle",
        "epochs": 20,
        "patience": 100,
        "dataset": "full",
        "optimizer": "auto",
        "training_time": 1.13, # in hours
        "path": os.path.join(rootFolder, "yolov11n_20_epochs", "results", "runs", "detect", "train", "results.csv"),
    },
    "yolov11n_20_epochs_adam_optimizer":
    {
        "model": "yolov11n",
        "platform": "kaggle",
        "epochs": 20,
        "patience": 100,
        "dataset": "full",
        "optimizer": "adam",
        "training_time": 0.14, # in hours
        "path": os.path.join(rootFolder, "yolov11n_20_epochs_adam_optimizer", "results", "train", "results.csv"),
    },
    "yolov11n_20_epochs_reduced_dataset":
    {
        "model": "yolov11n",
        "platform": "gtx 1060",
        "epochs": 20,
        "patience": 100,
        "dataset": "reduced",
        "optimizer": "auto",
        "training_time": 0.39, # in hours.minutes
        "path": os.path.join(rootFolder, "yolov11n_20_epochs_reduced_dataset", "detect", "train", "results.csv"),
    },
    "yolov11n_50_epochs_reduced_dataset":
    {
        "model": "yolov11n",
        "platform": "jetson",
        "epochs": 50,
        "patience": 100,
        "dataset": "reduced",
        "optimizer": "auto",
        "training_time": 1.38, # in hours.minutes
        "path": os.path.join(rootFolder, "yolov11n_50_epochs_reduced_dataset", "detect", "train", "results.csv"),
    },
    "yolov11n_100_epochs":
    {
        "model": "yolov11n",
        "platform": "kaggle",
        "epochs": 100,
        "patience": 100,
        "dataset": "full",
        "optimizer": "auto",
        "training_time": 4.24, # in hours
        "path": os.path.join(rootFolder, "yolov11n_100_epochs", "runs", "detect", "train", "results.csv"),
    },
    "yolov11n_250_epochs_10_patience_reduced_dataset":
    {
        "model": "yolov11n",
        "platform": "gtx 1060",
        "epochs": 250,
        "patience": 10,
        "dataset": "reduced",
        "optimizer": "auto",
        "training_time": 4.39, # in hours.minutes
        "path": os.path.join(rootFolder, "yolov11n_250_epochs_10_patience_reduced_dataset", "detect", "train", "results.csv"),
    },
    "yolov11n_250_epochs_adam_optimizer":
    {
        "model": "yolov11n",
        "platform": "kaggle",
        "epochs": 250,
        "patience": 100,
        "dataset": "full",
        "optimizer": "adam",
        #"training_time": 8.68, # in hours
        "path": os.path.join(rootFolder, "yolov11n_250_epochs_adam_optimizer", "results", "train", "results.csv"),
    },
     "yolov11n_100_epochs_adam_optimizer":
    {
        "model": "yolov11n",
        "platform": "kaggle",
        "epochs": 100,
        "patience": 100,
        "dataset": "full",
        "optimizer": "adam",
        "training_time": 1.13, # in hours
        "path": os.path.join(rootFolder, "yolov11n_100_epochs_adam_optimizer", "results", "train", "results.csv"),
    },
    "yolov11s_50_epochs":
    {
        "model": "yolov11s",
        "platform": "kaggle",
        "epochs": 50,
        "patience": 100,
        "dataset": "full",
        "optimizer": "auto",
        "training_time": 3.25, # in hours.minutes
        "path": os.path.join(rootFolder, "yolov11s_50_epochs", "runs", "detect", "train", "results.csv"),
    },
    "yolov11s_250_epochs_10_patience_reduced_dataset":
    {
        "model": "yolov11s",
        "platform": "gtx 1060",
        "epochs": 250,
        "patience": 10,
        "dataset": "reduced",
        "optimizer": "auto",
        "training_time": 4.58, # in hours.minutes
        "path": os.path.join(rootFolder, "yolov11s_250_epochs_10_patience_reduced_dataset", "detect", "train", "results.csv"),
    },
    "yolov11n_250_epochs_100_patience_reduced_dataset":
    {
        "model": "yolov11n",
        "platform": "gtx 1060",
        "epochs": 250,
        "patience": 100,
        "dataset": "reduced",
        "optimizer": "auto",
        "training_time": 8.3, # in hours.minutes
        "path": os.path.join(rootFolder, "yolov11n_250_epochs_100_patience_reduced_dataset", "detect", "train", "results.csv"),
    },
    "yolov11n_250_epochs_10_patience":
    {
        "model": "yolo11n",
        "platform": "kaggle",
        "epochs": 250,
        "patience": 10,
        "dataset": "full",
        "training_time": 11.1, # in hours
        "optimizer": "auto",
        "batch-size": 16,
        "path": os.path.join(rootFolder, "yolov11n_250_epochs_10_patience", "train", "results.csv"),
    },
}

# %% [markdown]
# ## Check provided paths

# %%
for key, value in trainingResults.items():
    if "path" in value.keys():
        if not os.path.exists(value["path"]):
            print(f"Key {key} doesn't contain file path {value['path']}!")
    else:
        print(f"Key {key} does not contain path!")
# Out:
# Key yolov11n_20_epochs_adam_optimizer does not contain path!
# Key yolov11n_250_epochs_adam_optimizer does not contain path!

# %% [markdown]
# ## Plot the data

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install numpy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plot YOLOv11n patience 10 vs patience 100

# %%
# Initialize lists to store the data
epochs = []
mAP5095 = []
mAP50 = []
labels = []

# Filter the trainingResults to include only the specified models
version_results = [trainingResults.get("yolov11n_250_epochs_100_patience_reduced_dataset"),
                   trainingResults.get("yolov11n_250_epochs_adam_optimizer")]

print(version_results[0])
print(version_results[1])
# Extract the data for the specified models
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        epochs.append(df['epoch'])
        mAP5095.append(df['metrics/precision(B)'])
        mAP50.append(df['metrics/recall(B)'])

        labels.append(model_info["model"] + " " + str(model_info["epochs"]) + " epochs " + model_info["optimizer"] + " optimizer")

# Plot the mAP metrics  
plt.figure(figsize=(20, 10))
for i in range(len(epochs)):
    plt.plot(epochs[i], mAP5095[i], label=labels[i] + " precision")
    plt.plot(epochs[i], mAP50[i], label=labels[i] + "  recall")
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.title('Precision and Recall metrics')
plt.legend()
# Out:
# {'model': 'yolov11n', 'platform': 'gtx 1060', 'epochs': 250, 'patience': 100, 'dataset': 'reduced', 'optimizer': 'auto', 'training_time': 8.3, 'path': 'results/yolov11n_250_epochs_100_patience_reduced_dataset/detect/train/results.csv'}
# {'model': 'yolov11n', 'platform': 'kaggle', 'epochs': 250, 'patience': 100, 'dataset': 'full', 'optimizer': 'adam', 'path': 'results/yolov11n_250_epochs_adam_optimizer/results/train/results.csv'}

# %%
# Initialize lists to store the data
epochs = []
mAP5095 = []
mAP50 = []
labels = []

# Filter the trainingResults to include only the specified models
version_results = [trainingResults.get("yolov11n_250_epochs_100_patience_reduced_dataset"),
                   trainingResults.get("yolov11n_250_epochs_adam_optimizer")]

print(version_results[0])
print(version_results[1])
# Extract the data for the specified models
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        epochs.append(df['epoch'])
        mAP5095.append(df['metrics/mAP50-95(B)'])
        mAP50.append(df['metrics/mAP50(B)'])

        labels.append(model_info["model"] + " " + str(model_info["epochs"]) + " epochs " + model_info["optimizer"] + " optimizer")

# Plot the mAP metrics  
plt.figure(figsize=(20, 10))
for i in range(len(epochs)):
    plt.plot(epochs[i], mAP5095[i], label=labels[i] + " mAP50-95")
    plt.plot(epochs[i], mAP50[i], label=labels[i] + "  mAP50")
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.title('mAP metrics')
plt.legend()
# Out:
# {'model': 'yolov11n', 'platform': 'gtx 1060', 'epochs': 250, 'patience': 100, 'dataset': 'reduced', 'optimizer': 'auto', 'training_time': 8.3, 'path': 'results/yolov11n_250_epochs_100_patience_reduced_dataset/detect/train/results.csv'}
# {'model': 'yolov11n', 'platform': 'kaggle', 'epochs': 250, 'patience': 100, 'dataset': 'full', 'optimizer': 'adam', 'path': 'results/yolov11n_250_epochs_adam_optimizer/results/train/results.csv'}

# %%
all_epochs = []
all_mAP5095 = []
all_recall = []
all_box= []

# Filter the trainingResults to include only the specified models
version_results = [trainingResults.get("yolov5nu_250_epochs_10_patience"), trainingResults.get("yolov11n_250_epochs_100_patience_reduced_dataset"), trainingResults.get("yolov11s_250_epochs_10_patience_reduced_dataset")]

# Determine the common range of epochs
min_epoch = float('inf')
max_epoch = float('-inf')
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        min_epoch = min(min_epoch, df['epoch'].min())
        max_epoch = max(max_epoch, df['epoch'].max())

# Create a common set of epochs
common_epochs = np.arange(min_epoch, max_epoch + 1)

# Extract the data for the specified models and interpolate to the common set of epochs
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        epochs = df['epoch']
        mAP5095 = df['val/dfl_loss']
        mAP50 = df['val/cls_loss']
        box = df['val/box_loss']
        
        # Interpolate the losses to the common set of epochs
        dfl_interp = np.interp(common_epochs, epochs, mAP5095)
        clss_interp = np.interp(common_epochs, epochs, mAP50)
        box_interp = np.interp(common_epochs, epochs, box)
        
        all_epochs.append(common_epochs)
        all_mAP5095.append(dfl_interp)
        all_recall.append(clss_interp)
        all_box.append(box_interp)

        labels.append(model_info["model"] + " " + str(model_info["epochs"]) + " epochs " + str(model_info["patience"]) + " patience")

# Plot the loss metrics
plt.figure(figsize=(20, 10))
for i in range(len(all_epochs)):
    plt.plot(all_epochs[i], all_mAP5095[i], label=labels[i] + " validation DFL Loss")
    plt.plot(all_epochs[i], all_recall[i], label=labels[i] + " validation Class Loss")
    plt.plot(all_epochs[i], all_box[i], label=labels[i] + " validation Box Loss")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss Metrics over Epochs')
plt.legend()
plt.show()

# %%
# Filter the trainingResults to include only the specified models
version_results = [trainingResults.get("yolov11n_250_epochs_100_patience")]

# Extract the data for the specified models and interpolate to the common set of epochs
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        epochs = df['epoch']
        mAP5095 = df['metrics/mAP50-95(B)']
        mAP50 = df['metrics/mAP50(B)']
        
        # Interpolate precision and recall to the common set of epochs
        mAP5095_interp = np.interp(common_epochs, epochs, mAP5095)
        mAP50_interp = np.interp(common_epochs, epochs, mAP50)
        
        all_epochs.append(common_epochs)
        all_mAP5095.append(mAP5095_interp)
        all_mAP50.append(mAP50_interp)

        labels.append(model_info["model"] + " " + str(model_info["epochs"]) + " epochs " + str(model_info["patience"]) + " patience")

# Plot the mAP metrics
plt.figure(figsize=(20, 10))
for i in range(len(all_epochs)):
    plt.plot(all_epochs[i], all_mAP5095[i], label=labels[i] + " mAP50-95")
    plt.plot(all_epochs[i], all_mAP50[i], label=labels[i] + " mAP50")
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.title('mAP50-95 and mAP50 over Epochs')
plt.legend()
plt.show()

# %%
all_epochs = []
all_mAP5095 = []
all_mAP50 = []

# Filter the trainingResults to include only the specified models
version_results = [trainingResults.get("yolov5nu_250_epochs_10_patience"), trainingResults.get("yolov11n_250_epochs_100_patience_reduced_dataset"), trainingResults.get("yolov11s_250_epochs_10_patience_reduced_dataset")]

# Determine the common range of epochs
min_epoch = float('inf')
max_epoch = float('-inf')
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        min_epoch = min(min_epoch, df['epoch'].min())
        max_epoch = max(max_epoch, df['epoch'].max())

# Create a common set of epochs
common_epochs = np.arange(min_epoch, max_epoch + 1)

# Extract the data for the specified models and interpolate to the common set of epochs
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        epochs = df['epoch']
        mAP5095 = df['metrics/mAP50-95(B)']
        mAP50 = df['metrics/mAP50(B)']
        
        # Interpolate precision and recall to the common set of epochs
        mAP5095_interp = np.interp(common_epochs, epochs, mAP5095)
        mAP50_interp = np.interp(common_epochs, epochs, mAP50)
        
        all_epochs.append(common_epochs)
        all_mAP5095.append(mAP5095_interp)
        all_mAP50.append(mAP50_interp)

        labels.append(model_info["model"] + " " + str(model_info["epochs"]) + " epochs " + str(model_info["patience"]) + " patience")

# Plot the mAP metrics
plt.figure(figsize=(20, 10))
for i in range(len(all_epochs)):
    plt.plot(all_epochs[i], all_mAP5095[i], label=labels[i] + " mAP50-95")
    plt.plot(all_epochs[i], all_mAP50[i], label=labels[i] + " mAP50")
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.title('mAP50-95 and mAP50 over Epochs')
plt.legend()
plt.show()

# %%
all_epochs = []
all_mAP5095 = []
all_= []

# Filter the trainingResults to include only the specified models
version_results = [trainingResults.get("yolov5nu_250_epochs_10_patience"), trainingResults.get("yolov11n_250_epochs_100_patience_reduced_dataset"), trainingResults.get("yolov11s_250_epochs_10_patience_reduced_dataset")]

# Determine the common range of epochs
min_epoch = float('inf')
max_epoch = float('-inf')
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        min_epoch = min(min_epoch, df['epoch'].min())
        max_epoch = max(max_epoch, df['epoch'].max())

# Create a common set of epochs
common_epochs = np.arange(min_epoch, max_epoch + 1)

# Extract the data for the specified models and interpolate to the common set of epochs
for model_info in version_results:
    if model_info and "path" in model_info:
        df = pd.read_csv(model_info["path"])
        epochs = df['epoch']
        mAP5095 = df['metrics/mAP50-95(B)']
        mAP50 = df['metrics/mAP50(B)']
        
        # Interpolate precision and recall to the common set of epochs
        mAP5095_interp = np.interp(common_epochs, epochs, mAP5095)
        mAP50_interp = np.interp(common_epochs, epochs, mAP50)
        
        all_epochs.append(common_epochs)
        all_mAP5095.append(mAP5095_interp)
        all_mAP50.append(mAP50_interp)

        labels.append(model_info["model"] + " " + str(model_info["epochs"]) + " epochs " + str(model_info["patience"]) + " patience")

# Plot the mAP metrics
plt.figure(figsize=(20, 10))
for i in range(len(all_epochs)):
    plt.plot(all_epochs[i], all_mAP5095[i], label=labels[i] + " mAP50-95")
    plt.plot(all_epochs[i], all_mAP50[i], label=labels[i] + " mAP50")
plt.xlabel('Epochs')
plt.ylabel('Metrics')
plt.title('mAP50-95 and mAP50 over Epochs')
plt.legend()
plt.show()
